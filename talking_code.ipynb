# %% [markdown]
# ![talking_code.png](attachment:7ec92386-f5b9-4787-8150-fd096a352a9d.png)

# %% [markdown]
# ## Talking Python Code - Text to Speech
# ### Joe Eberle started on:10_27_2022 updated on: 5/14/2025
# ### josepheberle@outlook.com      https:\\github\JoeEberle\\

# %%
first_install = False
if first_install:
    # !pip install pyttsx3
    # !pip install configparser

# %%
import pyttsx3
import talking_code as tc
import story_board as sb
import configparser as configparser
import os

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  
solution_name = 'talking_code'
cwd = os.getcwd()

# %% [markdown]
# ## Step 0 - Optional - Establish Logging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(True)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Process.')
# Out:
# Process talking_code Step 0 - Initializing and starting Process.

# %%
definition = '''

# 🗣️ Text-to-Speech for Your Python Code

Turn your code into a **talking assistant** using the `pyttsx3` library!
Make your apps easier to understand, more engaging, and accessible — all **offline**.

---

## 🔧 What is `pyttsx3`?

A lightweight Python library that lets you convert text to speech, without needing an internet connection.

## 💡 Key Features:

###  🧠 Works with **Python 2 & 3**

### 📢 Great for:

1.  Voice assistants
2.  Accessibility tools
3.  Educational apps

## 🚀 Why Use It?

1. 🎧 Let your code **talk to your users**
2. 💬 Add **spoken feedback** to apps and dashboards
3. 🤖 Build smarter, more human interfaces

''' 
sb.start_story(definition)
# Out:
# # 🗣️ Text-to-Speech for Your Python Code
#
# Turn your code into a **talking assistant** using the `pyttsx3` library!
# Make your apps easier to understand, more engaging, and accessible — all **offline**.
#
# ---
#
# ## 🔧 What is `pyttsx3`?
#
# A lightweight Python library that lets you convert text to speech, without needing an internet connection.
#
# ## 💡 Key Features:
#
# ###  🧠 Works with **Python 2 & 3**
#
# ### 📢 Great for:
#
# 1.  Voice assistants
# 2.  Accessibility tools
# 3.  Educational apps
#
# ## 🚀 Why Use It?
#
# 1. 🎧 Let your code **talk to your users**
# 2. 💬 Add **spoken feedback** to apps and dashboards
# 3. 🤖 Build smarter, more human interfaces

# %%
sb.add_image("sample.png")
# Out:
# ![Image](sample.png)

# %%
definition = '''

# 🗣️ Text-to-Speech for Your Python Code

## Process Steps :

1. **Import** the **pyttsx3** text to speech library
2. **Instantiate** the text to speech **engine**
3. **Configure** the TTS dialogues and settings
4. **Test** the Text to Speech Engine

''' 
sb.start_story(definition)
# Out:
# # 🗣️ Text-to-Speech for Your Python Code
#
# ## Process Steps :
#
# 1. **Import** the **pyttsx3** text to speech library
# 2. **Instantiate** the text to speech **engine**
# 3. **Configure** the TTS dialogues and settings
# 4. **Test** the Text to Speech Engine

# %% [markdown]
# ## Step 1 - Initialize The Text to Speech Engine

# %%
# Set text to speech preferences for project 
ql.pvlog('info',f'Process {solution_name} Step 1 - Initialize The Text to Speech Engine.') 
Text_to_Speech = tc.initialize_text_to_speech()
# Out:
# Process talking_code Step 1 - Initialize The Text to Speech Engine.

# %% [markdown]
# ## 🛠️ Text-to-Speech Setup: Step-by-Step
# ## 1️⃣ Import the Library

# %%
import pyttsx3
import talking_code as tc 
engine = pyttsx3.init()

# %% [markdown]
# ## 4️⃣ Speak Your First Words

# %%
tc.say("Hello! I'm your Python voice assistant.")

# %%
ql.pvlog('info',f'Process {solution_name} Step 3 - If speaking occurred then this process was successfull - End Process')
# Out:
# Process talking_code Step 3 - If speaking occurred then this process was successfull - End Process

# %%
sb.add_image("text_to_speach.png")
# Out:
# ![Image](text_to_speach.png)

# %% [markdown]
# ## Optional - Log overall performance and Append the Log File to Historical Log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2025-05-14 23:59:53,066 - INFO - START talking_code =============================================
# 2025-05-14 23:59:53,066 - INFO - START talking_code Start Time = 2025-05-14 23:59:53
# 2025-05-14 23:59:53,066 - INFO - talking_code Step 0 - Initialize the configuration file parser
# 2025-05-14 23:59:53,144 - INFO - Imported existing <module 'comtypes.gen' from 'C:\\Users\\josep\\anaconda3\\Lib\\site-packages\\comtypes\\gen\\__init__.py'>
# 2025-05-14 23:59:53,144 - INFO - Using writeable comtypes cache directory: 'C:\Users\josep\anaconda3\Lib\site-packages\comtypes\gen'
# 2025-05-14 23:59:59,080 - INFO - Process talking_code Step 0 - Initializing and starting Process.
# 2025-05-15 00:00:04,089 - INFO - Process talking_code Step 1 - Initialize The Text to Speech Engine.
# 2025-05-15 00:00:19,274 - INFO - Process talking_code Step 3 - If speaking occurred then this process was successfull - End Process
# ...

# %% [markdown]
# ![credits%20II%20.png](attachment:credits%20II%20.png)
