# %% [markdown]
# ![talking_code.png](attachment:talking_code.png)
# ## Talking Python Code - by Joe Eberle started on:10/27/2022
# #### josepheberle@outlook.com      https:\\github\JoeEberle\\

# %% [markdown]
# Process Steps :
# 1. Import the pyttsx3 text to speech module
# 2. Instantiate the text to speech engine
# 3. Configure the TTS dialogues and settings
# 4. Test the Text to Speech Engine

# %% [markdown]
# ![developer.png](attachment:developer.png)

# %%
first_install = True
if first_install:
    # !pip install pyttsx3
    # !pip install configparser
# Out:
# Requirement already satisfied: pyttsx3 in c:\users\josep\anaconda3\lib\site-packages (2.90)
# Requirement already satisfied: comtypes in c:\users\josep\anaconda3\lib\site-packages (from pyttsx3) (1.1.10)
# Requirement already satisfied: pywin32 in c:\users\josep\anaconda3\lib\site-packages (from pyttsx3) (305.1)
# Requirement already satisfied: pypiwin32 in c:\users\josep\anaconda3\lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: configparser in c:\users\josep\anaconda3\lib\site-packages (5.3.0)

# %%
import pyttsx3
import talking_code as talking_code
import configparser as configparser
import os

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  
solution_name = 'talking_code'
cwd = os.getcwd()

# %% [markdown]
# ## Step 0 - Optional - Establish Logging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(True)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Process.')
# Out:
# Process talking_code Step 0 - Initializing and starting Process.

# %%
Introduction =  "This data science solution will establish a text to speech engine. "
Introduction = Introduction + "The text to speech engine will allow you to have your code talk to the users.  "
Introduction = Introduction + "it will make your code easier to understand and use. "

talking_introduction  = True
if talking_introduction:
    ql.talk(Introduction)
else:
    print(Introduction)

# %% [markdown]
# ## Step 1 - Initialize The Text to Speech Engine

# %%
# Set text to speech preferences for project 
ql.pvlog('info',f'Process {solution_name} Step 1 - Initialize The Text to Speech Engine.') 
Text_to_Speech = talking_code.initialize_text_to_speech()
# Out:
# Process talking_code Step 1 - Initialize The Text to Speech Engine.

# %%
provide_documentation = True
if provide_documentation:  
        ql.pvlog('info',f'Process {solution_name} Step 2 - Read the Solution documentation.')     
        ql.talk(Introduction)
        credits = "This code was developed by Joe Eberle and Others"
        ql.talk(credits)
        process_steps = "The high level steps for this process are:"
        process_steps = process_steps + "Step 1 - Instantiate the text to speech engine"
        process_steps = process_steps + "Step 2 - Configure the TTS dialogues and settings"
        process_steps = process_steps + "Step 3 - Test the Text to Speech Engine"
        ql.talk(process_steps)  
        terms = 'The terminology for this project is:'
        terms = terms + 'The pyttsx3 library is a great library for text to speech. '
        ql.talk(terms)
# Out:
# Process talking_code Step 2 - Read the Solution documentation.

# %%
ql.pvlog('info',f'Process {solution_name} Step 3 - If speaking occurred then this process was successfull - End Process')
# Out:
# Process talking_code Step 3 - If speaking occurred then this process was successfull - End Process

# %% [markdown]
# ## Optional - Log overall performance and Append the Log File to Historical Log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2023-08-20 17:25:28,136 - INFO - START talking_code =============================================
# 2023-08-20 17:25:28,136 - INFO - START talking_code Start Time = 2023-08-20 17:25:28
# 2023-08-20 17:25:28,137 - INFO - talking_code Step 0 - Initialize the configuration file parser
# 2023-08-20 17:25:28,241 - INFO - Imported existing <module 'comtypes.gen' from 'C:\\Users\\josep\\anaconda3\\lib\\site-packages\\comtypes\\gen\\__init__.py'>
# 2023-08-20 17:25:28,241 - INFO - Using writeable comtypes cache directory: 'C:\Users\josep\anaconda3\lib\site-packages\comtypes\gen'
# 2023-08-20 17:25:33,788 - INFO - Process talking_code Step 0 - Initializing and starting Process.
# 2023-08-20 17:25:48,976 - INFO - Process talking_code Step 1 - Initialize The Text to Speech Engine.
# 2023-08-20 17:25:58,474 - INFO - Process talking_code Step 2 - Read the Solution documentation.
# 2023-08-20 17:26:34,080 - INFO - Process talking_code Step 3 - If speaking occurred then this process was successfull - End Process
# 2023-08-20 17:26:34,101 - INFO - PERFORMANCE talking_code The total process duration was:65.96
# 2023-08-20 17:26:34,101 - INFO - PERFORMANCE talking_code Stop Time = 2023-08-20 17:26:34
# 2023-08-20 17:26:34,101 - INFO - PERFORMANCE talking_code Low process duration less than 3 minutes:65.96
# 2023-08-20 17:26:34,101 - INFO - PERFORMANCE talking_code Performance optimization is optional
# 2023-08-20 17:26:34,101 - INFO - END talking_code =============================================

# %% [markdown]
# ## https://github.com/JoeEberle/
# ## josepheberle@outlook.com

# %% [markdown]
# ![developer.png](attachment:developer.png)
